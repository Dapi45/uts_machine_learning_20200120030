# %% [markdown]
# <a href="https://colab.research.google.com/github/Dapi45/uts_machine_learning_20200120030/blob/main/Daffi_Fadillah_20200120030_UTS_2_ML_TI_IS_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

dset = pd.read_csv('/content/drive/MyDrive/Datasets/UTS/dataset_uts-2021.csv')
dset
# Out:
#    No           Name                  Address  Mobile Phone   Project  \
# 0   1    Princy Odom        Street 1 New Lane   789456120.0    Client
# 1   2     Appy Alexa                Ac Street   568798821.0    Client
# 2   3      Luna Knox     PO.BOX 12-Loren Park           NaN       NaN
# 3   4  Clark Andrews   PO.BOX 156-Settle Road   123545342.0    Client
# 4   5     Riley Drew  PO.BOX 16-Thames Street   789821211.0   intenal
# 5   6    August Bork  PO.BOX 17-Thames Street   125921931.0  Internal
# 6   7     Riley Drew  PO.BOX 16-Thames Street   789821211.0  Internal
# 7   8            XYS        Street 12 New Way           0.0       NaN
# 8   9    Erica Flint   Street 7 New Lane Road   789456128.0  Internal
#
#              Email
# 0  princy@text.com
# 1    appy@text.com
# 2    luna@text.com
# 3   clark@text.com
# 4   riley@text.com
# 5     aug@text.com
# 6   riley@text.com
# 7              NaN
# 8   erica@text.com

# %%
dset.drop('No',inplace=True,axis=1)

# %%
dset = dset.dropna()
dset
# Out:
#             Name                  Address  Mobile Phone   Project  \
# 0    Princy Odom        Street 1 New Lane   789456120.0    Client
# 1     Appy Alexa                Ac Street   568798821.0    Client
# 3  Clark Andrews   PO.BOX 156-Settle Road   123545342.0    Client
# 4     Riley Drew  PO.BOX 16-Thames Street   789821211.0   intenal
# 5    August Bork  PO.BOX 17-Thames Street   125921931.0  Internal
# 6     Riley Drew  PO.BOX 16-Thames Street   789821211.0  Internal
# 8    Erica Flint   Street 7 New Lane Road   789456128.0  Internal
#
#              Email
# 0  princy@text.com
# 1    appy@text.com
# 3   clark@text.com
# 4   riley@text.com
# 5     aug@text.com
# 6   riley@text.com
# 8   erica@text.com

# %%
dset = dset.replace('intenal', 'Internal')
dset
# Out:
#             Name                  Address  Mobile Phone   Project  \
# 0    Princy Odom        Street 1 New Lane   789456120.0    Client
# 1     Appy Alexa                Ac Street   568798821.0    Client
# 3  Clark Andrews   PO.BOX 156-Settle Road   123545342.0    Client
# 4     Riley Drew  PO.BOX 16-Thames Street   789821211.0  Internal
# 5    August Bork  PO.BOX 17-Thames Street   125921931.0  Internal
# 6     Riley Drew  PO.BOX 16-Thames Street   789821211.0  Internal
# 8    Erica Flint   Street 7 New Lane Road   789456128.0  Internal
#
#              Email
# 0  princy@text.com
# 1    appy@text.com
# 3   clark@text.com
# 4   riley@text.com
# 5     aug@text.com
# 6   riley@text.com
# 8   erica@text.com

# %%
dset.dtypes
# Out:
# Name             object
# Address          object
# Mobile Phone    float64
# Project          object
# Email            object
# dtype: object

# %%
dset[['Mobile Phone']] = dset[['Mobile Phone']].astype('object')
dset.dtypes
# Out:
# Name            object
# Address         object
# Mobile Phone    object
# Project         object
# Email           object
# dtype: object

# %%
dset.rename(columns = {"Name": "Nama", "Address": "Alamat", "Mobile Phone": "Nomor Telepon", "Project": "Projek"}, inplace=True)
dset
# Out:
#             Nama                   Alamat Nomor Telepon    Projek  \
# 0    Princy Odom        Street 1 New Lane   789456120.0    Client
# 1     Appy Alexa                Ac Street   568798821.0    Client
# 3  Clark Andrews   PO.BOX 156-Settle Road   123545342.0    Client
# 4     Riley Drew  PO.BOX 16-Thames Street   789821211.0  Internal
# 5    August Bork  PO.BOX 17-Thames Street   125921931.0  Internal
# 6     Riley Drew  PO.BOX 16-Thames Street   789821211.0  Internal
# 8    Erica Flint   Street 7 New Lane Road   789456128.0  Internal
#
#              Email
# 0  princy@text.com
# 1    appy@text.com
# 3   clark@text.com
# 4   riley@text.com
# 5     aug@text.com
# 6   riley@text.com
# 8   erica@text.com

# %%
dset.to_csv('/content/drive/MyDrive/Datasets/UTS/clean_data_uts.csv', index=False)
datas=pd.read_csv('/content/drive/MyDrive/Datasets/UTS/clean_data_uts.csv')
datas
# Out:
#             Nama                   Alamat  Nomor Telepon    Projek  \
# 0    Princy Odom        Street 1 New Lane    789456120.0    Client
# 1     Appy Alexa                Ac Street    568798821.0    Client
# 2  Clark Andrews   PO.BOX 156-Settle Road    123545342.0    Client
# 3     Riley Drew  PO.BOX 16-Thames Street    789821211.0  Internal
# 4    August Bork  PO.BOX 17-Thames Street    125921931.0  Internal
# 5     Riley Drew  PO.BOX 16-Thames Street    789821211.0  Internal
# 6    Erica Flint   Street 7 New Lane Road    789456128.0  Internal
#
#              Email
# 0  princy@text.com
# 1    appy@text.com
# 2   clark@text.com
# 3   riley@text.com
# 4     aug@text.com
# 5   riley@text.com
# 6   erica@text.com

# %%
ds = datas.drop(5, axis=0)
ds
# Out:
#             Nama                   Alamat  Nomor Telepon    Projek  \
# 0    Princy Odom        Street 1 New Lane    789456120.0    Client
# 1     Appy Alexa                Ac Street    568798821.0    Client
# 2  Clark Andrews   PO.BOX 156-Settle Road    123545342.0    Client
# 3     Riley Drew  PO.BOX 16-Thames Street    789821211.0  Internal
# 4    August Bork  PO.BOX 17-Thames Street    125921931.0  Internal
# 6    Erica Flint   Street 7 New Lane Road    789456128.0  Internal
#
#              Email
# 0  princy@text.com
# 1    appy@text.com
# 2   clark@text.com
# 3   riley@text.com
# 4     aug@text.com
# 6   erica@text.com

# %%
ds.to_csv('/content/drive/MyDrive/Datasets/UTS/clean_data_uts2.csv', index=False)
daset=pd.read_csv('/content/drive/MyDrive/Datasets/UTS/clean_data_uts2.csv')
daset
# Out:
#             Nama                   Alamat  Nomor Telepon    Projek  \
# 0    Princy Odom        Street 1 New Lane    789456120.0    Client
# 1     Appy Alexa                Ac Street    568798821.0    Client
# 2  Clark Andrews   PO.BOX 156-Settle Road    123545342.0    Client
# 3     Riley Drew  PO.BOX 16-Thames Street    789821211.0  Internal
# 4    August Bork  PO.BOX 17-Thames Street    125921931.0  Internal
# 5    Erica Flint   Street 7 New Lane Road    789456128.0  Internal
#
#              Email
# 0  princy@text.com
# 1    appy@text.com
# 2   clark@text.com
# 3   riley@text.com
# 4     aug@text.com
# 5   erica@text.com
