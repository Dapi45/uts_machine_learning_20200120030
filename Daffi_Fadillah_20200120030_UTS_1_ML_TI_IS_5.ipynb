# %% [markdown]
# <a href="https://colab.research.google.com/github/Dapi45/uts_machine_learning_20200120030/blob/main/Daffi_Fadillah_20200120030_UTS_1_ML_TI_IS_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
path_="/content/drive/MyDrive/Datasets/UTS/top2018.csv"
## Link dataset: https://www.kaggle.com/datasets/nadintamer/top-spotify-tracks-of-2018

dataset=pd.read_csv(path_)
dataset
# Out:
#                        id                               name       artists  \
# 0   6DCZcSspjsKoFjzjrWoCd                         God's Plan         Drake
# 1   3ee8Jmje8o58CHK66QrVC                               SAD!  XXXTENTACION
# 2   0e7ipj03S05BNilyu5bRz         rockstar (feat. 21 Savage)   Post Malone
# 3   3swc6WTsr7rl9DqQKQA55       Psycho (feat. Ty Dolla $ign)   Post Malone
# 4   2G7V7zsVDxg1yRsu7Ew9R                     In My Feelings         Drake
# ..                    ...                                ...           ...
# 95  630sXRhIcfwr2e4RdNtjK                  Rewrite The Stars     Zac Efron
# 96  2xmrfQpmS2iJExTlklLoA  I Miss You (feat. Julia Michaels)  Clean Bandit
# 97  5WvAo7DNuPRmk4APhdPzi                         No Brainer     DJ Khaled
# 98  1j4kHkkpqZRBwE0A4CN4Y        Dusk Till Dawn - Radio Edit          ZAYN
# 99  3EPXxR3ImUwfayaurPi3c                         Be Alright    Dean Lewis
#
# ...

# %%
dataset.dtypes
# Out:
# id                   object
# name                 object
# artists              object
# danceability        float64
# energy              float64
# key                 float64
# loudness            float64
# mode                float64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# duration_ms         float64
# time_signature      float64
# dtype: object

# %%
dataset.describe()
# Out:
#        danceability      energy         key    loudness        mode  \
# count     100.00000  100.000000  100.000000  100.000000  100.000000
# mean        0.71646    0.659060    5.330000   -5.677640    0.590000
# std         0.13107    0.145067    3.676447    1.777577    0.494311
# min         0.25800    0.296000    0.000000  -10.109000    0.000000
# 25%         0.63550    0.562000    1.750000   -6.650500    0.000000
# 50%         0.73300    0.678000    5.000000   -5.566500    1.000000
# 75%         0.79825    0.772250    8.250000   -4.363750    1.000000
# max         0.96400    0.909000   11.000000   -2.384000    1.000000
#
#        speechiness  acousticness  instrumentalness    liveness     valence  \
# count   100.000000    100.000000        100.000000  100.000000  100.000000
# mean      0.115569      0.195701          0.001584    0.158302    0.484443
# std       0.104527      0.220946          0.013449    0.111662    0.206145
# ...

# %%
dataset['id'].is_unique
# Out:
# True

# %%
dataset=dataset.set_index('id')
dataset.head()
# Out:
#                                                name       artists  \
# id
# 6DCZcSspjsKoFjzjrWoCd                    God's Plan         Drake
# 3ee8Jmje8o58CHK66QrVC                          SAD!  XXXTENTACION
# 0e7ipj03S05BNilyu5bRz    rockstar (feat. 21 Savage)   Post Malone
# 3swc6WTsr7rl9DqQKQA55  Psycho (feat. Ty Dolla $ign)   Post Malone
# 2G7V7zsVDxg1yRsu7Ew9R                In My Feelings         Drake
#
#                        danceability  energy  key  loudness  mode  speechiness  \
# id
# 6DCZcSspjsKoFjzjrWoCd         0.754   0.449  7.0    -9.211   1.0       0.1090
# 3ee8Jmje8o58CHK66QrVC         0.740   0.613  8.0    -4.880   1.0       0.1450
# 0e7ipj03S05BNilyu5bRz         0.587   0.535  5.0    -6.090   0.0       0.0898
# 3swc6WTsr7rl9DqQKQA55         0.739   0.559  8.0    -8.011   1.0       0.1170
# 2G7V7zsVDxg1yRsu7Ew9R         0.835   0.626  1.0    -5.833   1.0       0.1250
#
#                        acousticness  instrumentalness  liveness  valence  \
# id
# ...

# %%
a = dataset[['danceability', 'energy']]
b = dataset[['acousticness', 'instrumentalness']]

# %%
a
# Out:
#                        danceability  energy
# id
# 6DCZcSspjsKoFjzjrWoCd         0.754   0.449
# 3ee8Jmje8o58CHK66QrVC         0.740   0.613
# 0e7ipj03S05BNilyu5bRz         0.587   0.535
# 3swc6WTsr7rl9DqQKQA55         0.739   0.559
# 2G7V7zsVDxg1yRsu7Ew9R         0.835   0.626
# ...                             ...     ...
# 630sXRhIcfwr2e4RdNtjK         0.684   0.619
# 2xmrfQpmS2iJExTlklLoA         0.638   0.658
# 5WvAo7DNuPRmk4APhdPzi         0.552   0.760
# 1j4kHkkpqZRBwE0A4CN4Y         0.258   0.437
# 3EPXxR3ImUwfayaurPi3c         0.553   0.586
#
# [100 rows x 2 columns]

# %%
b
# Out:
#                        acousticness  instrumentalness
# id
# 6DCZcSspjsKoFjzjrWoCd        0.0332          0.000083
# 3ee8Jmje8o58CHK66QrVC        0.2580          0.003720
# 0e7ipj03S05BNilyu5bRz        0.1170          0.000066
# 3swc6WTsr7rl9DqQKQA55        0.5800          0.000000
# 2G7V7zsVDxg1yRsu7Ew9R        0.0589          0.000060
# ...                             ...               ...
# 630sXRhIcfwr2e4RdNtjK        0.0716          0.000000
# 2xmrfQpmS2iJExTlklLoA        0.2450          0.000004
# 5WvAo7DNuPRmk4APhdPzi        0.0733          0.000000
# 1j4kHkkpqZRBwE0A4CN4Y        0.1010          0.000001
# 3EPXxR3ImUwfayaurPi3c        0.6970          0.000000
#
# [100 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
a_train,a_test=train_test_split(a,test_size=0.3) ## komposisi data training 70% dan data testing 30%

# %%
len(a_train)
# Out:
# 70

# %%
len(a_test)
# Out:
# 30

# %%
a_train
# Out:
#                        danceability  energy
# id
# 7uzmGiiJyRfuViKKK3lVm         0.710   0.789
# 5k38wzpLb15YgncyWdTZE         0.589   0.731
# 7ef4DlsgrMEH11cDZd32M         0.791   0.862
# 48zFZh27QU5qsrBjn4C2F         0.754   0.805
# 0WdGQhoAP2LBsqr5Jhit2         0.799   0.597
# ...                             ...     ...
# 77UjLW8j5UAGAGVGhR5oU         0.735   0.677
# 2QZ7WLBE8h2y1Y5Fb8RYb         0.622   0.712
# 2hl6q70unbviGo3g1R7uF         0.726   0.889
# 2G7V7zsVDxg1yRsu7Ew9R         0.835   0.626
# 0tBbt8CrmxbjRP0pueQky         0.720   0.807
#
# [70 rows x 2 columns]

# %%
a_test
# Out:
#                        danceability  energy
# id
# 3KLygy1YWhmrQx0GRs7IO         0.687   0.785
# 1j6xOGusnyXq3l6IryKF3         0.681   0.788
# 2BgEsaKNfHUdlh97KmvFy         0.697   0.683
# 09IStsImFySgyp0pIQdqA         0.753   0.657
# 3CA9pLiwRIGtUBiMjbZmR         0.586   0.909
# 2P91MQbaiQOfbiz9VqhqK         0.752   0.505
# 10Igtw8bSDyyFs7KIsKng         0.755   0.599
# 4QtiVmuA88tPQiCOHZuQ5         0.792   0.895
# 7KXjTSCq5nL1LoYtL7XAw         0.908   0.621
# 7AQim7LbvFVZJE3O8TYgf         0.797   0.533
# 5Z3GHaZ6ec9bsiI5Benrb         0.798   0.539
# 7sO5G9EABYOXQKNPNiE9N         0.880   0.428
# 5WvAo7DNuPRmk4APhdPzi         0.552   0.760
# 5Gu0PDLN4YJeW75PpBSg9         0.663   0.708
# 7vGuf3Y35N4wmASOKLUVV         0.520   0.761
# 08bNPGLD8AhKpnnERrAc6         0.626   0.880
# 6vN77lE9LK6HP2DewaN6H         0.964   0.346
# 2E124GmJRnBJuXbTb4cPU         0.931   0.387
# 2xJCMIJfcNYDc5iR0sAm2         0.762   0.700
# 1j4kHkkpqZRBwE0A4CN4Y         0.258   0.437
# ...

# %%
b_train,b_test=train_test_split(b,test_size=0.2) ## komposisi data training 80 dan data testing 20

# %%
len(b_train)
# Out:
# 80

# %%
len(b_test)
# Out:
# 20

# %%
b_train
# Out:
#                        acousticness  instrumentalness
# id
# 3swc6WTsr7rl9DqQKQA55       0.58000          0.000000
# 3ee8Jmje8o58CHK66QrVC       0.25800          0.003720
# 2P91MQbaiQOfbiz9VqhqK       0.53500          0.000003
# 7AFASza1mXqntmGtbxXpr       0.88300          0.000000
# 75ZvA4QfFiZvzhj2xkaWA       0.06890          0.000000
# ...                             ...               ...
# 58q2HKrzhC3ozto2nDdN4       0.09900          0.000000
# 4qKcDkK6siZ7Jp1Jb4m0a       0.00104          0.000059
# 1j4kHkkpqZRBwE0A4CN4Y       0.10100          0.000001
# 2G7V7zsVDxg1yRsu7Ew9R       0.05890          0.000060
# 6n4U3TlzUGhdSFbUUhTvL       0.07390          0.000000
#
# [80 rows x 2 columns]

# %%
b_test
# Out:
#                        acousticness  instrumentalness
# id
# 2ijef6ni2amuunRoKTlgw       0.35400          0.000029
# 1gm616Plq4ScqNi7TVkZ5       0.21800          0.000000
# 0tBbt8CrmxbjRP0pueQky       0.12900          0.000000
# 45Egmo7icyopuzJN0oMEd       0.09560          0.000000
# 76cy1WJvNGJTj78UqeA5z       0.04030          0.000000
# 3GCdLUSnKSMJhs4Tj6CV3       0.06050          0.000194
# 5OCJzvD7sykQEKHH7qAC3       0.02330          0.000060
# 0tgVpDi06FyKpA1z0VMD4       0.16300          0.000000
# 09IStsImFySgyp0pIQdqA       0.17100          0.000000
# 10Igtw8bSDyyFs7KIsKng       0.14700          0.000000
# 7GX5flRQZVHRAGd6B4TmD       0.00264          0.000000
# 0WdGQhoAP2LBsqr5Jhit2       0.07880          0.000006
# 5CLGzJsGqhCEECcpnFQA8       0.19400          0.000000
# 1ZAyjvIk9YiD76yYy0TEG       0.20200          0.000000
# 4eWQlBRaTjPPUlzacqEeo       0.18100          0.000637
# 2xJCMIJfcNYDc5iR0sAm2       0.00261          0.000016
# ...

# %%
dataset.head(10)
# Out:
#                                                name        artists  \
# id
# 6DCZcSspjsKoFjzjrWoCd                    God's Plan          Drake
# 3ee8Jmje8o58CHK66QrVC                          SAD!   XXXTENTACION
# 0e7ipj03S05BNilyu5bRz    rockstar (feat. 21 Savage)    Post Malone
# 3swc6WTsr7rl9DqQKQA55  Psycho (feat. Ty Dolla $ign)    Post Malone
# 2G7V7zsVDxg1yRsu7Ew9R                In My Feelings          Drake
# 7dt6x5M1jzdTEt8oCbisT                    Better Now    Post Malone
# 58q2HKrzhC3ozto2nDdN4                     I Like It        Cardi B
# 7ef4DlsgrMEH11cDZd32M      One Kiss (with Dua Lipa)  Calvin Harris
# 76cy1WJvNGJTj78UqeA5z                         IDGAF       Dua Lipa
# 08bNPGLD8AhKpnnERrAc6                       FRIENDS     Marshmello
#
#                        danceability  energy   key  loudness  mode  \
# id
# 6DCZcSspjsKoFjzjrWoCd         0.754   0.449   7.0    -9.211   1.0
# 3ee8Jmje8o58CHK66QrVC         0.740   0.613   8.0    -4.880   1.0
# ...

# %%
dataset.tail(10)
# Out:
#                                                      name        artists  \
# id
# 5N5k9nd479b1xpDZ4usjr           Promises (with Sam Smith)  Calvin Harris
# 6vN77lE9LK6HP2DewaN6H                          Yes Indeed       Lil Baby
# 2P91MQbaiQOfbiz9VqhqK                    I Like Me Better           Lauv
# 2xGjteMU3E1tkEPVFBO08                          This Is Me   Keala Settle
# 3GVkPk8mqxz0itaAriG1L  Everybody Dies In Their Nightmares   XXXTENTACION
# 630sXRhIcfwr2e4RdNtjK                   Rewrite The Stars      Zac Efron
# 2xmrfQpmS2iJExTlklLoA   I Miss You (feat. Julia Michaels)   Clean Bandit
# 5WvAo7DNuPRmk4APhdPzi                          No Brainer      DJ Khaled
# 1j4kHkkpqZRBwE0A4CN4Y         Dusk Till Dawn - Radio Edit           ZAYN
# 3EPXxR3ImUwfayaurPi3c                          Be Alright     Dean Lewis
#
#                        danceability  energy   key  loudness  mode  \
# id
# 5N5k9nd479b1xpDZ4usjr         0.781   0.768  11.0    -5.991   1.0
# ...

# %%
dataset.count()
# Out:
# name                100
# artists             100
# danceability        100
# energy              100
# key                 100
# loudness            100
# mode                100
# speechiness         100
# acousticness        100
# instrumentalness    100
# liveness            100
# valence             100
# tempo               100
# duration_ms         100
# time_signature      100
# dtype: int64

# %%
dataset.sort_values('danceability').head()
# Out:
#                                               name        artists  \
# id
# 1j4kHkkpqZRBwE0A4CN4Y  Dusk Till Dawn - Radio Edit           ZAYN
# 2xGjteMU3E1tkEPVFBO08                   This Is Me   Keala Settle
# 0u2P5u6lvoDfwTYjAADbn         lovely (with Khalid)  Billie Eilish
# 1gm616Plq4ScqNi7TVkZ5             Call Out My Name     The Weeknd
# 0s3nnoMeVWz3989MkNQiR                 Lucid Dreams     Juice WRLD
#
#                        danceability  energy   key  loudness  mode  \
# id
# 1j4kHkkpqZRBwE0A4CN4Y         0.258   0.437  11.0    -6.593   0.0
# 2xGjteMU3E1tkEPVFBO08         0.284   0.704   2.0    -7.276   1.0
# 0u2P5u6lvoDfwTYjAADbn         0.351   0.296   4.0   -10.109   0.0
# 1gm616Plq4ScqNi7TVkZ5         0.489   0.598   1.0    -4.929   1.0
# 0s3nnoMeVWz3989MkNQiR         0.511   0.566   6.0    -7.230   0.0
#
#                        speechiness  acousticness  instrumentalness  liveness  \
# id
# ...
